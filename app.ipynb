# %%
# !pip install jupyter-server-proxy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyter-server-proxy
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from jupyter-server-proxy) (3.8.5)
# Requirement already satisfied: jupyter-server>=1.24.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server-proxy) (2.11.1)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server-proxy) (6.3.2)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server-proxy) (5.9.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (4.8.0)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (21.3.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (6.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (5.9.2)
# Requirement already satisfied: overrides in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (7.4.0)
# Requirement already satisfied: packaging in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (24.2)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (0.14.1)
# Requirement already satisfied: pywinpty in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (25.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (0.17.1)
# Requirement already satisfied: websocket-client in c:\programdata\anaconda3\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy) (0.58.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from aiohttp->jupyter-server-proxy) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy) (1.2.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy) (3.8.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy) (306)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (4.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (6.0)
# Requirement already satisfied: referencing in c:\users\pc\appdata\roaming\python\python311\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (0.31.1)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (0.1.1)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (4.12.2)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (4.1.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy) (21.2.0)
# Requirement already satisfied: six in c:\users\pc\appdata\roaming\python\python311\site-packages (from websocket-client->jupyter-server>=1.24.0->jupyter-server-proxy) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (0.13.2)
# Requirement already satisfied: fqdn in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\programdata\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (2.1)
# Requirement already satisfied: uri-template in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (1.13)
# Requirement already satisfied: nest-asyncio in c:\users\pc\appdata\roaming\python\python311\site-packages (from nbclient>=0.5.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (1.5.6)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (2.4)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy) (0.5.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy) (1.2.3)
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Installing collected packages: simpervisor, jupyter-server-proxy
# Successfully installed jupyter-server-proxy-4.4.0 simpervisor-1.0.0

# %%
import streamlit as st
import joblib
import numpy as np
import base64
import json
from streamlit_lottie import st_lottie

# Load Models
models = {
    "Diabetes": joblib.load(r"C:\Users\pc\Desktop\med\Models\diabetes_rf_model.pkl"),
    "Heart Disease": joblib.load(r"C:\Users\pc\Desktop\med\Models\heart_disease_rf_model.pkl"),
    "Hypothyroid": joblib.load(r"C:\Users\pc\Desktop\med\Models\hypothyroid_rf_model.pkl"),
    "Lung Cancer": joblib.load(r"C:\Users\pc\Desktop\med\Models\lung_cancer_svc_model.pkl"),
    "Parkinson’s": joblib.load(r"C:\Users\pc\Desktop\med\Models\parkinsons_random_forest.pkl")
}

# Function to load Lottie animation
def load_lottie(url):
    return json.loads(url)

# Load Animations
loading_animation = load_lottie('https://lottie.host/9844-loading')
medical_animation = load_lottie('https://lottie.host/74045-medical-animation')
success_animation = load_lottie('https://lottie.host/17068-check-success')
error_animation = load_lottie('https://lottie.host/15791-error-animation')

# Set Page Config
st.set_page_config(page_title="Disease Prediction", page_icon="⚕️", layout="wide")

# Custom CSS
st.markdown("""
    <style>
    body {
        background-image: url('https://wallpaperaccess.com/full/3170189.jpg');
        background-size: cover;
        font-family: Arial, sans-serif;
    }
    .main-container {
        background: rgba(0, 0, 0, 0.8);
        padding: 20px;
        border-radius: 10px;
    }
    h1, h2, h3 {
        color: #00FFB3;
        text-align: center;
    }
    .stButton>button {
        background-color: #007BFF;
        color: white;
        border-radius: 10px;
    }
    </style>
""", unsafe_allow_html=True)

# Sidebar with animation
st.sidebar.title("⚕️ Disease Prediction AI")
st.sidebar.write("This app predicts **5 major diseases** using ML models.")
st_lottie(medical_animation, height=200, key="medical")

# Disease Selection
disease = st.sidebar.selectbox("Select a Disease", list(models.keys()))

# Input Fields
st.write(f"### Enter details for {disease}")

if disease == "Diabetes":
    inputs = [
        st.number_input("Pregnancies", 0, 20),
        st.number_input("Glucose", 0, 200),
        st.number_input("Blood Pressure", 0, 150),
        st.number_input("Skin Thickness", 0, 100),
        st.number_input("Insulin", 0, 900),
        st.number_input("BMI", 0.0, 70.0),
        st.number_input("Diabetes Pedigree", 0.0, 2.5),
        st.number_input("Age", 0, 120)
    ]
elif disease == "Heart Disease":
    inputs = [
        st.number_input("Age", 0, 120),
        st.number_input("Sex (0=Female, 1=Male)", 0, 1),
        st.number_input("Chest Pain Type (0-3)", 0, 3),
        st.number_input("Resting Blood Pressure", 80, 200),
        st.number_input("Cholesterol", 100, 600),
        st.number_input("Fasting Blood Sugar (0/1)", 0, 1),
        st.number_input("Resting ECG (0-2)", 0, 2),
        st.number_input("Max Heart Rate", 60, 220),
        st.number_input("Exercise Angina (0/1)", 0, 1),
        st.number_input("Oldpeak", -2.0, 6.0),
        st.number_input("Slope (0-2)", 0, 2),
        st.number_input("Ca (0-4)", 0, 4),
        st.number_input("Thal (0-3)", 0, 3)
    ]
elif disease == "Hypothyroid":
    inputs = [
        st.number_input("TSH", 0.0, 10.0),
        st.number_input("T3", 0.0, 5.0),
        st.number_input("TT4", 0.0, 200.0),
        st.number_input("T4U", 0.0, 2.0),
        st.number_input("FTI", 0.0, 200.0)
    ]
elif disease == "Lung Cancer":
    inputs = [
        st.number_input("Age", 0, 100),
        st.number_input("Smokes (0/1)", 0, 1),
        st.number_input("Coughing (0/1)", 0, 1),
        st.number_input("Shortness of Breath (0/1)", 0, 1),
        st.number_input("Wheezing (0/1)", 0, 1),
        st.number_input("Swallowing Difficulty (0/1)", 0, 1),
        st.number_input("Chest Pain (0/1)", 0, 1),
        st.number_input("Frequent Cold (0/1)", 0, 1),
        st.number_input("Fatigue (0/1)", 0, 1),
        st.number_input("Weight Loss (0/1)", 0, 1),
        st.number_input("Hoarseness (0/1)", 0, 1),
        st.number_input("Exposure to Pollution (0/1)", 0, 1),
        st.number_input("Exposure to Asbestos (0/1)", 0, 1),
        st.number_input("Family History (0/1)", 0, 1),
        st.number_input("Frequent Pneumonia (0/1)", 0, 1),
        st.number_input("Lung Nodules (0/1)", 0, 1)
    ]
elif disease == "Parkinson’s":
    inputs = [
        st.number_input("MDVP:Fo(Hz)", 50.0, 300.0),
        st.number_input("MDVP:Fhi(Hz)", 50.0, 300.0),
        st.number_input("MDVP:Flo(Hz)", 50.0, 300.0),
        st.number_input("Jitter(%)", 0.0, 0.1),
        st.number_input("Shimmer(dB)", 0.0, 1.0),
        st.number_input("HNR", 0.0, 50.0)
    ]

# Predict Button
if st.button("Predict"):
    st_lottie(loading_animation, height=150, key="loading")
    model = models[disease]
    prediction = model.predict(np.array(inputs).reshape(1, -1))

    if prediction[0] == 1:
        st_lottie(success_animation, height=200, key="success")
        st.success(f"The model predicts that you **may have {disease}**. Please consult a doctor.")
    else:
        st_lottie(error_animation, height=200, key="error")
        st.success(f"The model predicts that you **do NOT have {disease}**. Stay healthy!")
# Out:
# 2025-02-25 20:43:27.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:27.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 20:43:28.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run your_script.py
# Out:
# 'streamlit' is not recognized as an internal or external command,
# operable program or batch file.
